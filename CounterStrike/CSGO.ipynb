# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("patrasaurabh/csgo-player-and-team-stats")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 60.1k/60.1k [00:00<00:00, 3.16MB/s]
# Extracting files...
# Path to dataset files: /home/felipe/.cache/kagglehub/datasets/patrasaurabh/csgo-player-and-team-stats/versions/1
